# %%
import numpy as np
import pandas as pd
from numpy.random import randn
from pandas import Series,DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

# %matplotlib inline

# %%
dataset = randn(100)

# %%
sns.distplot(dataset,bins=25)

# %%
sns.distplot(dataset, bins=25,rug=True,hist=False)

# %%
sns.distplot(dataset,bins=25,
             kde_kws={'color':'indianred','label':'KDE PLOT'},
             hist_kws={'color':'blue','label':'HIST'})

# %%
ser1=Series(dataset,name='Мои данные')
ser1
# Out:
# 0    -1.120022
# 1    -0.768341
# 2     0.357205
# 3    -0.578296
# 4    -0.400337
# 5     0.273228
# 6    -0.140014
# 7     1.860209
# 8    -0.688582
# 9    -1.348473
# 10    0.464302
# 11    0.125621
# 12    0.489037
# 13    1.105788
# 14    0.586609
# 15   -0.428000
# 16    0.231253
# 17    1.834892
# 18    0.678053
# 19    0.050775
# 20   -1.693713
# 21    0.026354
# 22   -1.342531
# 23    0.986561
# 24    0.426689
# 25    0.486585
# 26   -0.730308
# 27    0.413825
# 28    0.182416
# 29    0.763225
#         ...
# 70   -0.374872
# 71   -1.928858
# 72    0.374380
# 73    0.044338
# 74   -1.528323
# 75   -0.659254
# 76    0.363833
# 77    0.160107
# 78    0.342400
# 79    0.428919
# 80    1.391380
# 81   -0.293500
# 82   -0.965968
# 83    0.461614
# 84   -0.418263
# 85    1.407265
# 86   -1.136391
# 87    0.097720
# 88   -0.800942
# 89    0.008047
# 90   -0.271797
# 91    1.420327
# 92    0.942967
# 93    2.136305
# 94   -0.442868
# 95    0.791545
# 96   -0.282879
# 97   -0.703725
# 98    0.439191
# 99   -1.595611
# Name: Мои данные, dtype: float64

# %%
sns.distplot(ser1,bins=25)
